# %% [markdown]
# # Reto 2 - Piedra, papel o tijera
#
# Este es un juego en el que nunca fui bueno, pero eso no significa que hacer un programa sea difícil. Escribe un programa que reciba como parámetro “piedra”, “papel”, o “tijera” y determine si ganó el jugador 1 o el jugador 2.
#
# **Bonus: determina que el ganador sea el jugador que gane 2 de 3 encuentros.**
#
# Ejemplo:
#
# ```ppt(“piedra”, “papel”) ➞ “El ganador es el jugador 2```

# %%
import random

# %%
def ai():
    opciones = ('piedra', 'papel', 'tijera')
    eleccion = 
    return eleccion

# %%
vic_p1 = 0
vic_ai = 0

while vic_p1 < 2 and vic_ai < 2:
    
    opciones = ('piedra', 'papel', 'tijera')
    
    print("""Elige para jugar:
    0. Piedra
    1. Papel
    2. Tijera
    """)
    
    p1 = int(input())
    
    ai = random.choice(opciones)
    
    if not type(p1) is int:
        raise TypeError('Solo puede ingresar números')
    elif p1 < 0 or p1 > 2:
        raise ValueError('Solo se permiten números entre 0 y 2')
    
    if opciones[p1] == ai:
        print('Es un empate...')
    elif opciones[p1] == 'piedra' and ai == 'tijera':
        vic_p1 += 1
        print('Gana el jugador #1')
    elif opciones[p1] == 'tijera' and ai == 'papel':
        vic_p1 += 1
        print('Gana el jugador #1')
    elif opciones[p1] == 'papel'and ai == 'piedra':
        vic_p1 += 1
        print('Gana el jugador #1')
    else:
        vic_ai += 1
        print('Gana la IA')
    print(f'\nMarcador :::::::::::::: P1 {vic_p1} ::: IA {vic_ai} ::::::::::::::\n')
print('::::::::::::: FIN DEL JUEGO ::::::::::')
ganador = 'Victoria para el JUGADOR 1' if vic_p1 == 3 else 'Victoria para la IA'
print(ganador)
# Out:
# Elige para jugar:
#     0. Piedra
#     1. Papel
#     2. Tijera
#
# 0
# Es un empate...
#
# Marcador :::::::::::::: P1 0 ::: IA 0 ::::::::::::::
#
# Elige para jugar:
#     0. Piedra
#     1. Papel
#     2. Tijera
#
# 1
# Gana el jugador #1
#
# Marcador :::::::::::::: P1 1 ::: IA 0 ::::::::::::::
#
# Elige para jugar:
#     0. Piedra
#     1. Papel
#     2. Tijera
#
# 1
# Gana la IA
#
# Marcador :::::::::::::: P1 1 ::: IA 1 ::::::::::::::
#
# Elige para jugar:
#     0. Piedra
#     1. Papel
#     2. Tijera
#
# 1
# Es un empate...
#
# Marcador :::::::::::::: P1 1 ::: IA 1 ::::::::::::::
#
# Elige para jugar:
#     0. Piedra
#     1. Papel
#     2. Tijera
#
# 1
# Es un empate...
#
# Marcador :::::::::::::: P1 1 ::: IA 1 ::::::::::::::
#
# Elige para jugar:
#     0. Piedra
#     1. Papel
#     2. Tijera
#
# 1
# Es un empate...
#
# Marcador :::::::::::::: P1 1 ::: IA 1 ::::::::::::::
#
# Elige para jugar:
#     0. Piedra
#     1. Papel
#     2. Tijera
#
# 1
# Gana el jugador #1
#
# ...
